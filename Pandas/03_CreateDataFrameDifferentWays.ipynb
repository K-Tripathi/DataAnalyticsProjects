# %%
import pandas as pd
df = pd.read_csv("/Users/komal13tripathi/Desktop/PandaslearningWeather/weather.csv", skiprows=18)
df
# Out:
#     1/18/2016  25   6  53  29.83   9    12     T  2      Snow  293
# 0   1/19/2016  22   3  42  30.03  10  11.0     0  1       NaN  293
# 1   1/20/2016  32  15  49  30.13  10   6.0     0  2       NaN  302
# 2   1/21/2016  31  11  45  30.15  10   6.0     0  1       NaN  312
# 3   1/22/2016  26   6  41  30.21   9   NaN  0.01  3      Snow   34
# 4   1/23/2016  26  21  78  29.77   1  16.0  2.31  8  Fog-Snow   42
# 5   1/24/2016  28  11  53  29.92   8   6.0     T  3      Snow  327
# 6   1/25/2016  34  18  54  30.25  10   3.0     0  2       NaN  286
# 7   1/26/2016  43  29  56  30.03  10   7.0     0  2       NaN  244
# 8   1/27/2016  41  22  45  30.03  10   7.0     T  3      Rain  311
# 9   1/28/2016  37  20  51  29.90  10   5.0     0  1       NaN  234
# 10  1/29/2016  36  21  50  29.58  10   8.0     0  4       NaN  298
# 11  1/30/2016  34  16  46  30.01  10   7.0     0  0       NaN  257
# 12  1/31/2016  46  28  52  29.90  10   5.0     0  0       NaN  241

# %%
df = pd.read_csv("/Users/komal13tripathi/Desktop/PandaslearningWeather/weather.csv", nrows=3)
df
# Out:
#         EST  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 0  1/1/2016           38        23        52                 30.03
# 1  1/2/2016           36        18        46                 30.02
# 2  1/3/2016           40        21        47                 29.86
#
#    VisibilityMiles  WindSpeedMPH  PrecipitationIn  CloudCover  Events  \
# 0               10             8                0           5     NaN
# 1               10             7                0           3     NaN
# 2               10             8                0           1     NaN
#
#    WindDirDegrees
# 0             281
# 1             275
# 2             277

# %%
df = pd.read_csv("/Users/komal13tripathi/Desktop/PandaslearningWeather/weather.csv", na_values=[293])
df
# Out:
#           EST  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 0    1/1/2016           38        23        52                 30.03
# 1    1/2/2016           36        18        46                 30.02
# 2    1/3/2016           40        21        47                 29.86
# 3    1/4/2016           25         9        44                 30.05
# 4    1/5/2016           20        -3        41                 30.57
# 5    1/6/2016           33         4        35                 30.50
# 6    1/7/2016           39        11        33                 30.28
# 7    1/8/2016           39        29        64                 30.20
# 8    1/9/2016           44        38        77                 30.16
# 9   1/10/2016           50        46        71                 29.59
# 10  1/11/2016           33         8        37                 29.92
# 11  1/12/2016           35        15        53                 29.85
# 12  1/13/2016           26         4        42                 29.94
# ...

# %%
df.to_csv("/Users/komal13tripathi/Desktop/PandaslearningWeather/new.csv")

# %%
df.to_csv("/Users/komal13tripathi/Desktop/PandaslearningWeather/new.csv", index=False)

# %%
df.columns
# Out:
# Index(['EST', 'Temperature', 'DewPoint', 'Humidity', 'Sea Level PressureIn',
#        'VisibilityMiles', 'WindSpeedMPH', 'PrecipitationIn', 'CloudCover',
#        'Events', 'WindDirDegrees'],
#       dtype='object')

# %%
df.to_csv("/Users/komal13tripathi/Desktop/PandaslearningWeather/new1.csv", columns=['EST', 'Temperature'])

# %%
df.to_csv("/Users/komal13tripathi/Desktop/PandaslearningWeather/new2.csv", header=False)
